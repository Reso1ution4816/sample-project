# %% [markdown]
# ## 决策树
# 由节点和对应的算法组成. <br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np

credit = pd.read_excel('credit_risk.xlsx')
X = credit[['less2yrs', 'missedpay']].as_matrix()
y = credit['defaulted'].as_matrix()


def gini_impurity(y):
#   assume y are all integers
    p_i = np.bincount(y) / y.shape[0]
    return 1 - np.sum(p_i ** 2)


def gini_index(y_left, y_right):
    l_count, r_count = y_left.shape[0], y_right.shape[0]
    all_count = l_count + r_count
    
    l_imp = gini_impurity(y_left)
    r_imp = gini_impurity(y_right)
    
    return l_count/all_count * l_imp + r_count/all_count * r_imp


def get_best_split(X, y):
    min_gini_index = 1.0
    best_split = {}
    for i in range(X.shape[1]): 
        col = X[:, i]
        thresholds = np.unique(col)
        for th in thresholds:
            left_mask = col <= th
            right_mask =  col > th

            gi = gini_index(y[left_mask], y[right_mask])
#             print('column=',i, 'thres=', th, 'gini_index=',gi)
            if gi < min_gini_index:
                min_gini_index = gi
                best_split = {'left mask':left_mask, 
                              'right mask':right_mask, 
                              'feature index':i, 
                              'threshold':th, 
                              'gini index':gi}
    return best_split


class DecisionNode():
    def __init__(self, impurity=1.0):
        self.feature_index = None   # 从第几个feature分割数据集
        self.threshold = None       # 按照什么样的值分割数据集
        self.label = None           # 如果节点是叶子, node具有对应的标签
        self.true_branch = None     # 'Left' subtree
        self.false_branch = None    # 'Right' subtree
        self.impurity = impurity    # impurity最大是 1.0
        
    def __str__(self):
        return ' '.join(['feature %s,'%self.feature_index, 
                         'threshold %s,'%self.threshold, 
                         'impurity %s,'%self.impurity, 
                         'label %s'%self.label])
    
    def __repr__(self):
        return self.__str__()

# 生成决策树
def build_tree(X, y):
    best_split = get_best_split(X, y)
    
    node = DecisionNode(impurity=gini_impurity(y))
    
    # if X,y can be split for lower impurity
    if best_split['gini index'] < node.impurity:
#         print(best_split['gini index'], node.impurity)
        
        node.feature_index = best_split['feature index']
        node.threshold = best_split['threshold']
        
        left, right = best_split['left mask'], best_split['right mask']
        
        node.true_branch =  build_tree(X[left], y[left])
        node.false_branch =  build_tree(X[right], y[right])
    else:
        
        node.label = np.argmax(np.bincount(y))
        
    
    return node

# 利用决策树预测样本
def tree_predict(tree, x):
    pred = None
    if tree.label is not None:
        pred = tree.label
    else:
        if x[tree.feature_index] <= tree.threshold:
            pred = tree_predict(tree.true_branch, x)
        else:
            pred = tree_predict(tree.false_branch, x)
    return pred


def prediction(tree, X):
    y_pred = []
    for row in X:
        y_pred.append(tree_predict(dt, row))
    return y_pred


def accuracy(y, y_pred):
    y, y_pred = np.array(y), np.array(y_pred)
    return (y_pred == y).sum()/y.shape[0]
    
dt = build_tree(X, y)

print(accuracy(y, prediction(dt, X)))

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

X, y = load_iris(return_X_y=True)


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

dt = build_tree(X_train, y_train)

print(accuracy(y_test, prediction(dt, X_test)))
# Out:
# 0.8
# 0.96

# %%
movie = pd.read_csv('movie_metadata.csv')

# %%
movie.describe(include='all')
# Out:
#         color     director_name  num_critic_for_reviews     duration  \
# count    5024              4939             4993.000000  5028.000000
# unique      2              2398                     NaN          NaN
# top     Color  Steven Spielberg                     NaN          NaN
# freq     4815                26                     NaN          NaN
# mean      NaN               NaN              140.194272   107.201074
# std       NaN               NaN              121.601675    25.197441
# min       NaN               NaN                1.000000     7.000000
# 25%       NaN               NaN               50.000000    93.000000
# 50%       NaN               NaN              110.000000   103.000000
# 75%       NaN               NaN              195.000000   118.000000
# max       NaN               NaN              813.000000   511.000000
#
#         director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# count               4939.000000             5020.000000            5030
# unique                      NaN                     NaN            3032
# top                         NaN                     NaN  Morgan Freeman
# freq                        NaN                     NaN              20
# mean                 686.509212              645.009761             NaN
# std                 2813.328607             1665.041728             NaN
# min                    0.000000                0.000000             NaN
# 25%                    7.000000              133.000000             NaN
# 50%                   49.000000              371.500000             NaN
# 75%                  194.500000              636.000000             NaN
# max                23000.000000            23000.000000             NaN
#
#         actor_1_facebook_likes         gross genres         ...           \
# count              5036.000000  4.159000e+03   5043         ...
# unique                     NaN           NaN    914         ...
# top                        NaN           NaN  Drama         ...
# freq                       NaN           NaN    236         ...
# mean               6560.047061  4.846841e+07    NaN         ...
# std               15020.759120  6.845299e+07    NaN         ...
# min                   0.000000  1.620000e+02    NaN         ...
# 25%                 614.000000  5.340988e+06    NaN         ...
# 50%                 988.000000  2.551750e+07    NaN         ...
# 75%               11000.000000  6.230944e+07    NaN         ...
# max              640000.000000  7.605058e+08    NaN         ...
#
#        num_user_for_reviews language  country  content_rating        budget  \
# count           5022.000000     5031     5038            4740  4.551000e+03
# unique                  NaN       47       65              18           NaN
# top                     NaN  English      USA               R           NaN
# freq                    NaN     4704     3807            2118           NaN
# mean             272.770808      NaN      NaN             NaN  3.975262e+07
# std              377.982886      NaN      NaN             NaN  2.061149e+08
# min                1.000000      NaN      NaN             NaN  2.180000e+02
# 25%               65.000000      NaN      NaN             NaN  6.000000e+06
# 50%              156.000000      NaN      NaN             NaN  2.000000e+07
# 75%              326.000000      NaN      NaN             NaN  4.500000e+07
# max             5060.000000      NaN      NaN             NaN  1.221550e+10
#
#          title_year actor_2_facebook_likes   imdb_score  aspect_ratio  \
# count   4935.000000            5030.000000  5043.000000   4714.000000
# unique          NaN                    NaN          NaN           NaN
# top             NaN                    NaN          NaN           NaN
# freq            NaN                    NaN          NaN           NaN
# mean    2002.470517            1651.754473     6.442138      2.220403
# std       12.474599            4042.438863     1.125116      1.385113
# min     1916.000000               0.000000     1.600000      1.180000
# 25%     1999.000000             281.000000     5.800000      1.850000
# 50%     2005.000000             595.000000     6.600000      2.350000
# 75%     2011.000000             918.000000     7.200000      2.350000
# max     2016.000000          137000.000000     9.500000     16.000000
#
#        movie_facebook_likes
# count           5043.000000
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean            7525.964505
# std            19320.445110
# min                0.000000
# 25%                0.000000
# 50%              166.000000
# 75%             3000.000000
# max           349000.000000
#
# [11 rows x 28 columns]

# %%
import matplotlib.pyplot as plt
movie['imdb_score'].plot.box()
plt.show()

# %%
from sklearn.datasets import fetch_olivetti_faces
faces = fetch_olivetti_faces(shuffle=True, random_state=True)
X, y = faces.data, faces.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

dt = build_tree(X_train, y_train)

print(accuracy(y_test, prediction(dt, X_test)))
# 0.462121212121
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-79116de11b74> in <module>()
#       6     X, y, test_size=0.33, random_state=42)
#       7
# ----> 8 dt = build_tree(X_train, y_train)
#       9
#      10 print(accuracy(y_test, prediction(dt, X_test)))
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      79
#      80         node.true_branch =  build_tree(X[left], y[left])
# ---> 81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#      83
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      78         left, right = best_split['left mask'], best_split['right mask']
#      79
# ---> 80         node.true_branch =  build_tree(X[left], y[left])
#      81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      79
#      80         node.true_branch =  build_tree(X[left], y[left])
# ---> 81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#      83
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      79
#      80         node.true_branch =  build_tree(X[left], y[left])
# ---> 81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#      83
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      78         left, right = best_split['left mask'], best_split['right mask']
#      79
# ---> 80         node.true_branch =  build_tree(X[left], y[left])
#      81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      79
#      80         node.true_branch =  build_tree(X[left], y[left])
# ---> 81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#      83
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      79
#      80         node.true_branch =  build_tree(X[left], y[left])
# ---> 81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#      83
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      79
#      80         node.true_branch =  build_tree(X[left], y[left])
# ---> 81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#      83
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      79
#      80         node.true_branch =  build_tree(X[left], y[left])
# ---> 81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#      83
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      78         left, right = best_split['left mask'], best_split['right mask']
#      79
# ---> 80         node.true_branch =  build_tree(X[left], y[left])
#      81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      78         left, right = best_split['left mask'], best_split['right mask']
#      79
# ---> 80         node.true_branch =  build_tree(X[left], y[left])
#      81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      78         left, right = best_split['left mask'], best_split['right mask']
#      79
# ---> 80         node.true_branch =  build_tree(X[left], y[left])
#      81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      79
#      80         node.true_branch =  build_tree(X[left], y[left])
# ---> 81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#      83
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      79
#      80         node.true_branch =  build_tree(X[left], y[left])
# ---> 81         node.false_branch =  build_tree(X[right], y[right])
#      82     else:
#      83
#
# <ipython-input-3-9b8881e87aad> in build_tree(X, y)
#      65 # 生成决策树
#      66 def build_tree(X, y):
# ---> 67     best_split = get_best_split(X, y)
#      68
#      69     node = DecisionNode(impurity=gini_impurity(y))
#
# <ipython-input-3-9b8881e87aad> in get_best_split(X, y)
#      33             right_mask =  col > th
#      34
# ---> 35             gi = gini_index(y[left_mask], y[right_mask])
#      36 #             print('column=',i, 'thres=', th, 'gini_index=',gi)
#      37             if gi < min_gini_index:
#
# <ipython-input-3-9b8881e87aad> in gini_index(y_left, y_right)
#      18
#      19     l_imp = gini_impurity(y_left)
# ---> 20     r_imp = gini_impurity(y_right)
#      21
#      22     return l_count/all_count * l_imp + r_count/all_count * r_imp
#
# <ipython-input-3-9b8881e87aad> in gini_impurity(y)
#       9 def gini_impurity(y):
#      10 #   assume y are all integers
# ---> 11     p_i = np.bincount(y) / y.shape[0]
#      12     return 1 - np.sum(p_i ** 2)
#      13
#
# KeyboardInterrupt:

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(DecisionTreeClassifier(), X, y, cv=5, n_jobs=-1)
# Out:
# array([ 0.96666667,  0.96666667,  0.9       ,  0.93333333,  1.        ])

# %%
import glob, os
workdir = 'C:/Users/iota/catvdog/train'
for file in glob.glob(os.path.join(workdir, 'cat.*.jpg')):
    print(file)
# Out:
# C:/Users/iota/catvdog/train\cat.0.jpg
# C:/Users/iota/catvdog/train\cat.1.jpg
# C:/Users/iota/catvdog/train\cat.10.jpg
# C:/Users/iota/catvdog/train\cat.100.jpg
# C:/Users/iota/catvdog/train\cat.1000.jpg
# C:/Users/iota/catvdog/train\cat.10000.jpg
# C:/Users/iota/catvdog/train\cat.10001.jpg
# C:/Users/iota/catvdog/train\cat.10002.jpg
# C:/Users/iota/catvdog/train\cat.10003.jpg
# C:/Users/iota/catvdog/train\cat.10004.jpg
# C:/Users/iota/catvdog/train\cat.10005.jpg
# C:/Users/iota/catvdog/train\cat.10006.jpg
# C:/Users/iota/catvdog/train\cat.10007.jpg
# C:/Users/iota/catvdog/train\cat.10008.jpg
# C:/Users/iota/catvdog/train\cat.10009.jpg
# C:/Users/iota/catvdog/train\cat.1001.jpg
# C:/Users/iota/catvdog/train\cat.10010.jpg
# C:/Users/iota/catvdog/train\cat.10011.jpg
# C:/Users/iota/catvdog/train\cat.10012.jpg
# C:/Users/iota/catvdog/train\cat.10013.jpg
# C:/Users/iota/catvdog/train\cat.10014.jpg
# C:/Users/iota/catvdog/train\cat.10015.jpg
# C:/Users/iota/catvdog/train\cat.10016.jpg
# C:/Users/iota/catvdog/train\cat.10017.jpg
# C:/Users/iota/catvdog/train\cat.10018.jpg
# C:/Users/iota/catvdog/train\cat.10019.jpg
# C:/Users/iota/catvdog/train\cat.1002.jpg
# C:/Users/iota/catvdog/train\cat.10020.jpg
# C:/Users/iota/catvdog/train\cat.9981.jpg
# C:/Users/iota/catvdog/train\cat.9982.jpg
# C:/Users/iota/catvdog/train\cat.9983.jpg
# C:/Users/iota/catvdog/train\cat.9984.jpg
# C:/Users/iota/catvdog/train\cat.9985.jpg
# C:/Users/iota/catvdog/train\cat.9986.jpg
# C:/Users/iota/catvdog/train\cat.9987.jpg
# C:/Users/iota/catvdog/train\cat.9988.jpg
# C:/Users/iota/catvdog/train\cat.9989.jpg
# C:/Users/iota/catvdog/train\cat.999.jpg
# C:/Users/iota/catvdog/train\cat.9990.jpg
# C:/Users/iota/catvdog/train\cat.9991.jpg
# C:/Users/iota/catvdog/train\cat.9992.jpg
# C:/Users/iota/catvdog/train\cat.9993.jpg
# C:/Users/iota/catvdog/train\cat.9994.jpg
# C:/Users/iota/catvdog/train\cat.9995.jpg
# C:/Users/iota/catvdog/train\cat.9996.jpg
# C:/Users/iota/catvdog/train\cat.9997.jpg
# C:/Users/iota/catvdog/train\cat.9998.jpg
# C:/Users/iota/catvdog/train\cat.9999.jpg

# %%
def test_dump(X, y, save_path):
    if os.path.exists(save_path):
        res = pd.read_excel(save_path)
    else:
        accs = {}
        
        random_states = (np.random.rand(50) * 2**16).astype(int)
        for max_depth in [10, 20, 50, 100, 200, 500, 1000]:
            accs[max_depth] = []
            for random_state in range(random_states):
                X_train, X_test, y_train, y_test = train_test_split(
                    X, y, test_size=0.33, random_state=random_state)

                clf = DecisionTreeClassifier(max_depth=max_depth).fit(X_train, y_train)
                accs[max_depth].append(accuracy(y_test, clf.predict(X_test)))

        res = pd.DataFrame(accs)
        res.to_excel(save_path)
    return res

# %%
from sklearn.tree import DecisionTreeClassifier
otto = pd.read_csv('otto_group.csv')
X = otto.drop(['id', 'target'], axis=1)
y = otto['target']
X_train, X_test, y_train, y_test = train_test_split(
                    X, y, test_size=0.33, random_state=42)
clf = DecisionTreeClassifier(max_depth=2).fit(X_train, y_train)
accuracy(y_test, clf.predict(X_test))
# Out:
# 0.43991185112634673

# %%
import matplotlib.pyplot as plt
import pandas as pd
credit = pd.read_excel('credit_risk.xlsx')
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

mtrx = credit.as_matrix()
print(mtrx.shape)
x = mtrx[:, :-1]
y = mtrx[:, -1]

clf = DecisionTreeClassifier(max_depth=2)
clf.fit(x, y)
# requires additional installation of graphviz
file_name = 'credit_risk.dot'
tree.export_graphviz(clf, out_file=file_name, impurity=True, node_ids=True, 
                     class_names=['good', 'bad'], feature_names=credit.columns[[0,1]])
# from subprocess import check_call
# check_call(['dot', '-Tpng', file_name, '-o', file_name + '.png'])
# Out:
# (10, 3)

# %%
from sklearn.datasets import fetch_olivetti_faces
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import os

faces = fetch_olivetti_faces(shuffle=True, random_state=True)
X, y = faces.data, faces.target
X, y = load_iris(return_X_y=True)

save_path = 'iris_decision_tree_depth.xlsx'

res = test_dump(X, y, save_path)
res.mean().plot()
import matplotlib.pyplot as plt
plt.show()

# %%
res.mean().plot()
import matplotlib.pyplot as plt
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X, y)
print(accuracy(y, clf.predict(X)))
